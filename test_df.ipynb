# %%
import pandas as pd 

df = pd.read_csv('bpjs_train_small.csv')

# %%
import matplotlib.pyplot as plt
df['fraud_type'].value_counts()
# Out:
# fraud_type
# none                      101999
# graph_star_spoke           16000
# phantom_billing            13501
# graph_ring_network         12000
# graph_clique_collusion      4500
# graph_star_center           2000
# Name: count, dtype: int64
